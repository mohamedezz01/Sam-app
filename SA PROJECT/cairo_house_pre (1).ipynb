# %%
import pandas as pd
import seaborn as sbs
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
import os

# %%
os.chdir(r"D:\machine learning")
data = pd.read_csv("cairo_house.csv")
data
# Out:
#     Square_Meter  Age_of_house  Total_rooms  Total_Bath  Floor        City  \
# 0             75             1            1           1      1      Helwan
# 1            100             4            2           1      3  El_Zamalek
# 2            125             3            3           2      4      Helwan
# 3            115             2            3           1      9      Shobra
# 4             79             5            1           1      5    El_Maadi
# ..           ...           ...          ...         ...    ...         ...
# 57           191             5            4           2      7      Shobra
# 58           210             2            5           3      4    El_Maadi
# 59           161             2            3           2      2      Helwan
# 60           190             2            3           2      6      Helwan
# 61           200             1            4           3      1      Shobra
#
#         Price
# 0   1674939.9
# 1   3579991.5
# 2   2504969.8
# 3   2435038.5
# 4   1984928.5
# ..        ...
# 57  3624928.7
# 58  4110090.0
# 59  3044968.8
# 60  3480038.2
# 61  3779973.9
#
# [62 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Square_Meter  62 non-null     int64
#  1   Age_of_house  62 non-null     int64
#  2   Total_rooms   62 non-null     int64
#  3   Total_Bath    62 non-null     int64
#  4   Floor         62 non-null     int64
#  5   City          62 non-null     object
#  6   Price         62 non-null     float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 3.5+ KB

# %%
data.describe()
# Out:
#        Square_Meter  Age_of_house  Total_rooms  Total_Bath      Floor  \
# count     62.000000     62.000000    62.000000   62.000000  62.000000
# mean     147.016129      2.451613     2.983871    1.806452   4.612903
# std       45.745014      1.237096     1.234636    0.623020   2.569396
# min       75.000000      1.000000     1.000000    1.000000   1.000000
# 25%      105.500000      1.000000     2.000000    1.000000   3.000000
# 50%      148.500000      2.000000     3.000000    2.000000   4.000000
# 75%      188.750000      3.000000     4.000000    2.000000   6.750000
# max      250.000000      5.000000     5.000000    3.000000   9.000000
#
#               Price
# count  6.200000e+01
# mean   3.272029e+06
# std    8.673130e+05
# min    1.674940e+06
# 25%    2.624970e+06
# 50%    3.310000e+06
# 75%    3.838835e+06
# max    5.189939e+06

# %%
data["City"]
# Out:
# 0         Helwan
# 1     El_Zamalek
# 2         Helwan
# 3         Shobra
# 4       El_Maadi
#          ...
# 57        Shobra
# 58      El_Maadi
# 59        Helwan
# 60        Helwan
# 61        Shobra
# Name: City, Length: 62, dtype: object

# %%
data["City"].unique()
# Out:
# array(['Helwan', 'El_Zamalek', 'Shobra', 'El_Maadi'], dtype=object)

# %%
data_city = pd.get_dummies(data["City"],dtype="int64")
data_city
# Out:
#     El_Maadi  El_Zamalek  Helwan  Shobra
# 0          0           0       1       0
# 1          0           1       0       0
# 2          0           0       1       0
# 3          0           0       0       1
# 4          1           0       0       0
# ..       ...         ...     ...     ...
# 57         0           0       0       1
# 58         1           0       0       0
# 59         0           0       1       0
# 60         0           0       1       0
# 61         0           0       0       1
#
# [62 rows x 4 columns]

# %%
data = pd.concat([data,data_city],axis=1)
data
# Out:
#     Square_Meter  Age_of_house  Total_rooms  Total_Bath  Floor        City  \
# 0             75             1            1           1      1      Helwan
# 1            100             4            2           1      3  El_Zamalek
# 2            125             3            3           2      4      Helwan
# 3            115             2            3           1      9      Shobra
# 4             79             5            1           1      5    El_Maadi
# ..           ...           ...          ...         ...    ...         ...
# 57           191             5            4           2      7      Shobra
# 58           210             2            5           3      4    El_Maadi
# 59           161             2            3           2      2      Helwan
# 60           190             2            3           2      6      Helwan
# 61           200             1            4           3      1      Shobra
#
#         Price  El_Maadi  El_Zamalek  Helwan  Shobra
# 0   1674939.9         0           0       1       0
# 1   3579991.5         0           1       0       0
# 2   2504969.8         0           0       1       0
# 3   2435038.5         0           0       0       1
# 4   1984928.5         1           0       0       0
# ..        ...       ...         ...     ...     ...
# 57  3624928.7         0           0       0       1
# 58  4110090.0         1           0       0       0
# 59  3044968.8         0           0       1       0
# 60  3480038.2         0           0       1       0
# 61  3779973.9         0           0       0       1
#
# [62 rows x 11 columns]

# %%
data = data.drop(["City"],axis=1)
data
# Out:
#     Square_Meter  Age_of_house  Total_rooms  Total_Bath  Floor      Price  \
# 0             75             1            1           1      1  1674939.9
# 1            100             4            2           1      3  3579991.5
# 2            125             3            3           2      4  2504969.8
# 3            115             2            3           1      9  2435038.5
# 4             79             5            1           1      5  1984928.5
# ..           ...           ...          ...         ...    ...        ...
# 57           191             5            4           2      7  3624928.7
# 58           210             2            5           3      4  4110090.0
# 59           161             2            3           2      2  3044968.8
# 60           190             2            3           2      6  3480038.2
# 61           200             1            4           3      1  3779973.9
#
#     El_Maadi  El_Zamalek  Helwan  Shobra
# 0          0           0       1       0
# 1          0           1       0       0
# 2          0           0       1       0
# 3          0           0       0       1
# 4          1           0       0       0
# ..       ...         ...     ...     ...
# 57         0           0       0       1
# 58         1           0       0       0
# 59         0           0       1       0
# 60         0           0       1       0
# 61         0           0       0       1
#
# [62 rows x 10 columns]

# %%
Y = data["Price"]
X = data.drop("Price",axis=1)
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,Y_test)
# Out:
# 0.9901863411044746

# %%
model.coef_
# Out:
# array([  12610.3167779 ,  -26116.05384856,   90733.41679575,
#          44948.43812978,    8750.87833391, -266429.29847992,
#        1149264.44536374, -503813.58169097, -379021.56519285])

# %%
model.intercept_
# Out:
# 1148156.4762605876

# %%
s = int(input())
a = int(input())
r = int(input())
b = int(input())
f = int(input())
h = int(input())
z = int(input())
sh = int(input())
m = int(input())
model.predict([[s,a,r,b,f,h,z,sh,m]])
# Out:
# 150
# 1
# 3
# 2
# 1
# 0
# 0
# 1
# 0
# D:\Anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2880622.36238689])
